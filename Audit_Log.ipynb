# %%
# %sql
CREATE SCHEMA workspace.audit;

# %%
# %sql
CREATE TABLE workspace.audit.pipeline_log
(
pipeline_name STRING,
execution_time TIMESTAMP,
records_processed BIGINT,
status STRING
)
USING DELTA;
